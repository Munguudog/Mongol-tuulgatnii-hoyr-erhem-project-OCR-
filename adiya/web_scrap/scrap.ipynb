# %%
import json
import requests
from bs4 import BeautifulSoup
import time


BASE_URL = "http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews="  
OUTPUT_FILE = "scraped_data.json"

start_index = 50
end_index = 2560

scraped_data = []

for index in range(start_index, end_index + 1):
    url = f"{BASE_URL}{index}"
    print(f"Scraping: {url}")
    
    try:
        response = requests.get(url, timeout=10)
        response.raise_for_status()
        soup = BeautifulSoup(response.text, "html.parser")
        
        div_element = soup.find("div", class_="news_text_t transform")
        extracted_text = div_element.get_text(strip=True) if div_element else ""
        
        scraped_data.append({"index": index, "text": extracted_text})
    except requests.RequestException as e:
        print(f"Error fetching {url}: {e}")
    time.sleep(1)

# Save data to JSON file
with open(OUTPUT_FILE, "w", encoding="utf-8") as f:
    json.dump(scraped_data, f, ensure_ascii=False, indent=4)

print(f"Scraping complete. Data saved to {OUTPUT_FILE}")
# Out:
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=50
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=51
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=52
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=53
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=54
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=55
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=56
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=57
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=58
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=59
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=60
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=61
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=62
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=63
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=64
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=65
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=66
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=67
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=68
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=69
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=70
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=71
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=72
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=73
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=74
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=75
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=76
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=77
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=78
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=79
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=80
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=81
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=82
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=83
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=84
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=85
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=86
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=87
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=88
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=89
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=90
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=91
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=92
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=93
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=94
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=95
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=96
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=97
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=98
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=99
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=100
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=101
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=102
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=103
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=104
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=105
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=106
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=107
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=108
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=109
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=110
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=111
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=112
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=113
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=114
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=115
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=116
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=117
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=118
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=119
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=120
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=121
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=122
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=123
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=124
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=125
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=126
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=127
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=128
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=129
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=130
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=131
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=132
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=133
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=134
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=135
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=136
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=137
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=138
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=139
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=140
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=141
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=142
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=143
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=144
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=145
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=146
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=147
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=148
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=149
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=150
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=151
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=152
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=153
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=154
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=155
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=156
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=157
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=158
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=159
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=160
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=161
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=162
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=163
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=164
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=165
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=166
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=167
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=168
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=169
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=170
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=171
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=172
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=173
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=174
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=175
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=176
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=177
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=178
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=179
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=180
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=181
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=182
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=183
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=184
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=185
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=186
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=187
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=188
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=189
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=190
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=191
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=192
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=193
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=194
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=195
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=196
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=197
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=198
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=199
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=200
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=201
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=202
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=203
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=204
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=205
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=206
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=207
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=208
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=209
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=210
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=211
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=212
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=213
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=214
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=215
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=216
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=217
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=218
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=219
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=220
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=221
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=222
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=223
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=224
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=225
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=226
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=227
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=228
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=229
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=230
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=231
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=232
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=233
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=234
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=235
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=236
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=237
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=238
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=239
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=240
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=241
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=242
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=243
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=244
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=245
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=246
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=247
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=248
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=249
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=250
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=251
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=252
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=253
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=254
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=255
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=256
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=257
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=258
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=259
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=260
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=261
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=262
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=263
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=264
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=265
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=266
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=267
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=268
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=269
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=270
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=271
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=272
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=273
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=274
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=275
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=276
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=277
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=278
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=279
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=280
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=281
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=282
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=283
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=284
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=285
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=286
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=287
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=288
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=289
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=290
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=291
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=292
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=293
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=294
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=295
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=296
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=297
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=298
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=299
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=300
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=301
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=302
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=303
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=304
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=305
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=306
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=307
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=308
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=309
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=310
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=311
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=312
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=313
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=314
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=315
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=316
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=317
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=318
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=319
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=320
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=321
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=322
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=323
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=324
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=325
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=326
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=327
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=328
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=329
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=330
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=331
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=332
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=333
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=334
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=335
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=336
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=337
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=338
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=339
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=340
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=341
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=342
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=343
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=344
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=345
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=346
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=347
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=348
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=349
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=350
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=351
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=352
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=353
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=354
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=355
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=356
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=357
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=358
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=359
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=360
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=361
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=362
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=363
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=364
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=365
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=366
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=367
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=368
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=369
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=370
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=371
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=372
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=373
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=374
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=375
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=376
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=377
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=378
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=379
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=380
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=381
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=382
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=383
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=384
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=385
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=386
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=387
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=388
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=389
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=390
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=391
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=392
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=393
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=394
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=395
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=396
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=397
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=398
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=399
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=400
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=401
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=402
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=403
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=404
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=405
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=406
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=407
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=408
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=409
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=410
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=411
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=412
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=413
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=414
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=415
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=416
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=417
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=418
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=419
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=420
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=421
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=422
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=423
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=424
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=425
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=426
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=427
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=428
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=429
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=430
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=431
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=432
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=433
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=434
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=435
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=436
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=437
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=438
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=439
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=440
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=441
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=442
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=443
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=444
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=445
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=446
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=447
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=448
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=449
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=450
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=451
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=452
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=453
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=454
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=455
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=456
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=457
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=458
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=459
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=460
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=461
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=462
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=463
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=464
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=465
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=466
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=467
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=468
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=469
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=470
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=471
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=472
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=473
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=474
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=475
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=476
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=477
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=478
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=479
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=480
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=481
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=482
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=483
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=484
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=485
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=486
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=487
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=488
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=489
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=490
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=491
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=492
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=493
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=494
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=495
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=496
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=497
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=498
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=499
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=500
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=501
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=502
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=503
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=504
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=505
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=506
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=507
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=508
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=509
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=510
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=511
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=512
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=513
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=514
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=515
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=516
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=517
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=518
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=519
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=520
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=521
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=522
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=523
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=524
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=525
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=526
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=527
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=528
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=529
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=530
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=531
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=532
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=533
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=534
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=535
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=536
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=537
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=538
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=539
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=540
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=541
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=542
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=543
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=544
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=545
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=546
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=547
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=548
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=549
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=550
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=551
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=552
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=553
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=554
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=555
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=556
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=557
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=558
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=559
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=560
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=561
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=562
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=563
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=564
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=565
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=566
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=567
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=568
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=569
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=570
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=571
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=572
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=573
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=574
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=575
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=576
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=577
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=578
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=579
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=580
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=581
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=582
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=583
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=584
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=585
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=586
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=587
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=588
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=589
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=590
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=591
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=592
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=593
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=594
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=595
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=596
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=597
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=598
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=599
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=600
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=601
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=602
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=603
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=604
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=605
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=606
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=607
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=608
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=609
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=610
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=611
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=612
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=613
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=614
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=615
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=616
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=617
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=618
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=619
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=620
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=621
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=622
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=623
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=624
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=625
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=626
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=627
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=628
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=629
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=630
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=631
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=632
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=633
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=634
# ...
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=2369
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=2370
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=2371
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=2372
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=2373
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=2374
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=2375
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=2376
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=2377
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=2378
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=2379
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=2380
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=2381
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=2382
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=2383
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=2384
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=2385
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=2386
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=2387
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=2388
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=2389
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=2390
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=2391
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=2392
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=2393
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=2394
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=2395
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=2396
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=2397
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=2398
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=2399
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=2400
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=2401
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=2402
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=2403
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=2404
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=2405
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=2406
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=2407
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=2408
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=2409
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=2410
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=2411
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=2412
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=2413
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=2414
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=2415
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=2416
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=2417
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=2418
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=2419
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=2420
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=2421
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=2422
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=2423
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=2424
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=2425
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=2426
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=2427
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=2428
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=2429
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=2430
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=2431
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=2432
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=2433
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=2434
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=2435
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=2436
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=2437
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=2438
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=2439
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=2440
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=2441
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=2442
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=2443
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=2444
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=2445
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=2446
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=2447
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=2448
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=2449
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=2450
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=2451
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=2452
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=2453
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=2454
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=2455
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=2456
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=2457
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=2458
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=2459
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=2460
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=2461
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=2462
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=2463
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=2464
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=2465
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=2466
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=2467
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=2468
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=2469
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=2470
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=2471
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=2472
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=2473
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=2474
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=2475
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=2476
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=2477
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=2478
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=2479
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=2480
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=2481
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=2482
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=2483
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=2484
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=2485
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=2486
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=2487
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=2488
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=2489
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=2490
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=2491
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=2492
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=2493
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=2494
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=2495
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=2496
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=2497
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=2498
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=2499
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=2500
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=2501
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=2502
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=2503
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=2504
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=2505
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=2506
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=2507
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=2508
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=2509
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=2510
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=2511
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=2512
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=2513
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=2514
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=2515
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=2516
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=2517
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=2518
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=2519
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=2520
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=2521
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=2522
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=2523
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=2524
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=2525
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=2526
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=2527
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=2528
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=2529
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=2530
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=2531
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=2532
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=2533
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=2534
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=2535
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=2536
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=2537
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=2538
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=2539
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=2540
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=2541
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=2542
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=2543
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=2544
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=2545
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=2546
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=2547
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=2548
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=2549
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=2550
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=2551
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=2552
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=2553
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=2554
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=2555
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=2556
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=2557
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=2558
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=2559
# Scraping: http://khumuunbichig.montsame.mn/index.php?command=newsall&readnews=2560
# Scraping complete. Data saved to scraped_data.json

# %%
with open("scraped_data.json") as f:
    data = json.load(f)

# %%
import json
from collections import Counter

# Load the scraped JSON data
with open("scraped_data.json", "r", encoding="utf-8") as f:
    data = json.load(f)

# Initialize character and word counters
char_counter = Counter()
word_counter = Counter()
total_word_count = 0

# Process each extracted text
for entry in data:
    text = entry["text"]
    
    # Count characters
    char_counter.update(text)
    
    # Count words (splitting by whitespace)
    words = text.split()
    word_counter.update(words)
    total_word_count += len(words)

# Get unique counts
unique_chars = len(char_counter)
unique_words = len(word_counter)

# Print results
print(f"Total unique characters: {unique_chars}")
print(f"Character frequencies: {dict(char_counter)}")
print(f"Total words: {total_word_count}")
print(f"Total unique words: {unique_words}")
# Out:
# Total unique characters: 97
# Character frequencies: {'b': 59283, 'u': 27597, 'l': 120067, 'i': 251125, 't': 41194, '\xa0': 132848, 'o': 304666, 'a': 176760, ' ': 440195, 'D': 64548, 'g': 61292, 'e': 436514, '&': 39070, '1': 8140, '7': 1647, 'd': 100118, '*': 36064, 'J': 19522, 'r': 87437, 'O': 84099, '<': 13866, 'f': 107136, 's': 44569, '>': 13830, 'k': 74344, 'E': 103977, 'm': 31602, 'K': 36875, 'M': 18282, 'H': 22940, 'B': 32473, 'S': 28857, '%': 8477, 'N': 20932, 'h': 36135, '_': 11439, 'Y': 12430, 'c': 38491, 'I': 69844, 'C': 9189, ',': 41053, 'j': 37355, '0': 9018, '^': 9470, '(': 13674, '.': 18711, '\r': 34193, '\n': 34192, '\t': 3652, 'y': 15552, '9': 1992, '3': 2748, 'Z': 1869, 'A': 10550, '8': 1680, '6': 1784, 'G': 9568, '5': 2623, ')': 13245, 'n': 19306, '2': 8541, '4': 2396, 'w': 9527, 'W': 572, ']': 582, '-': 8997, '=': 1940, 'L': 1708, ':': 238, '"': 241, '$': 2399, 'T': 20726, '[': 1347, 'q': 784, 'z': 432, '|': 1424, '?': 742, '~': 764, 'P': 1226, '!': 469, '`': 49, 'p': 2513, '{': 126, 'R': 521, 'Q': 194, '\\': 2931, '#': 201, 'F': 1397, '}': 65, 'U': 13342, '@': 50, '+': 56, ';': 631, '/': 11, '\u200c': 1, '\xad': 1, 'у': 1}
# Total words: 578170
# Total unique words: 29354

# %%
from fontTools.ttLib import TTFont
from PIL import Image, ImageDraw, ImageFont
import os

# Load the WOFF font
font_path = "CMsHureedp.woff"
font_path = "cmsulaanbaatardp-webfont.woff"


def extract_and_save_glyph_images(woff_file, output_dir):
    # Load the WOFF file using TTFont
    font = TTFont(woff_file)
    
    # Get the 'cmap' table which contains the Unicode to Glyph ID mappings
    cmap = font['cmap']
    
    # Loop through the cmap encodings and extract Unicode to Glyph ID mapping
    unicode_glyph_mapping = {}
    for table in cmap.tables:
        for char_code, glyph_id in table.cmap.items():
            unicode_glyph_mapping[char_code] = glyph_id
    
    # Create the output directory if it doesn't exist
    if not os.path.exists(output_dir):
        os.makedirs(output_dir)
    
    # Print and save the glyph images
    print(f"Total number of glyphs: {len(unicode_glyph_mapping)}")
    print("Rendering glyphs as images...")
    
    for unicode_code, glyph_id in unicode_glyph_mapping.items():
        # Get the standard character from the Unicode code point
        standard_char = chr(unicode_code)
        
        # Create an image to render the glyph
        image = Image.new('RGB', (50, 50), color=(255, 255, 255))  # White background
        draw = ImageDraw.Draw(image)
        
        # Load the font to render the character
        try:
            font_path = font.reader.file.name  # Path to the font file
            image_font = ImageFont.truetype(font_path, 40)  # Adjust font size as needed
        except Exception as e:
            print(f"Error loading font: {e}")
            continue
        # Draw the Unicode character on the image
        draw.text((5, 5), standard_char, font=image_font, fill=(0, 0, 0))  # Black text
        
        # Save the image with the glyph's ID as the filename
        image_filename = os.path.join(output_dir, f"glyph_{glyph_id}_U+{unicode_code:04X}.png")
        image.save(image_filename)
        print(f"Saved: {image_filename}")
        return unicode_glyph_mapping

# Example usage?
woff_file = font_path
output_dir = "glyph_images"  # Directory where the images will be saved
my_map = extract_and_save_glyph_images(woff_file, output_dir)

# %%
from fontTools.ttLib import TTFont
from PIL import Image, ImageDraw, ImageFont
import os

def extract_and_render_glyphs(woff_file, output_image, glyphs_per_row=5, font_size=40, padding=20, box_size=80):
    # Load the WOFF font
    font = TTFont(woff_file)
    cmap = font['cmap']
    unicode_glyph_mapping = {}
    
    for table in cmap.tables:
        for char_code, glyph_id in table.cmap.items():
            unicode_glyph_mapping[char_code] = glyph_id
    
    glyph_count = len(unicode_glyph_mapping)
    rows = (glyph_count + glyphs_per_row - 1) // glyphs_per_row  # Calculate total rows
    img_width = glyphs_per_row * box_size + padding
    img_height = rows * box_size + padding
    
    # Create the output image
    image = Image.new('RGB', (img_width, img_height), color=(255, 255, 255))
    draw = ImageDraw.Draw(image)
    
    try:
        image_font = ImageFont.truetype(woff_file, font_size)
    except Exception as e:
        print(f"Error loading font: {e}")
        return
    
    # Render glyphs
    x, y = padding, padding
    print(len(unicode_glyph_mapping))
    for idx, (unicode_code, glyph_id) in enumerate(unicode_glyph_mapping.items()):
        char = chr(unicode_code)
        box_coords = [x, y, x + box_size, y + box_size]
        draw.rectangle(box_coords, outline='black', width=2)
        text_x = x + (box_size - font_size) // 2
        text_y = y + (box_size - font_size) // 2
        draw.text((text_x, text_y), char, font=image_font, fill='black')
        
        x += box_size
        if (idx + 1) % glyphs_per_row == 0:
            x = padding
            y += box_size
    
    image.save(output_image)
    print(f"Saved glyph overview: {output_image}")

# Example usage
# woff_file = "khuree_font/cmsulaanbaatardp-webfont.woff"
woff_file = "khuree_font/CMSUB.TTF"
output_image = "glyph_overview1.png"
extract_and_render_glyphs(woff_file, output_image)
# Out:
# 124
# Saved glyph overview: glyph_overview1.png

# %%
from fontTools.ttLib import TTFont
from PIL import Image, ImageDraw, ImageFont

def visualize_chars_in_font(woff_file, output_image, chars, glyphs_per_row=5, font_size=40, padding=20, box_size=80):
    # Load the font
    font = TTFont(woff_file)
    cmap = font['cmap']
    unicode_glyph_mapping = {}
    
    for table in cmap.tables:
        for char_code, glyph_id in table.cmap.items():
            unicode_glyph_mapping[char_code] = glyph_id

    # Create the output image
    rows = (len(chars) + glyphs_per_row - 1) // glyphs_per_row
    img_width = glyphs_per_row * box_size + padding
    img_height = rows * box_size + padding

    image = Image.new('RGB', (img_width, img_height), color=(255, 255, 255))
    draw = ImageDraw.Draw(image)

    # Load font for rendering
    try:
        image_font = ImageFont.truetype(woff_file, font_size)
    except Exception as e:
        print(f"Error loading font: {e}")
        return

    # Render each character
    x, y = padding, padding
    for idx, char in enumerate(chars):
        # Draw box around each character
        box_coords = [x, y, x + box_size, y + box_size]
        draw.rectangle(box_coords, outline='black', width=2)
        
        # Check if the character is supported
        unicode_code = ord(char)
        if unicode_code not in unicode_glyph_mapping:
            print(f"Character '{char}', unicode {unicode_code} not supported in font")
        # Center the character in the box
        text_x = x + (box_size - font_size) // 2
        text_y = y + (box_size - font_size) // 2
        draw.text((text_x, text_y), char, font=image_font, fill='black')
        
        
        # Move to next box
        x += box_size
        if (idx + 1) % glyphs_per_row == 0:
            x = padding
            y += box_size

    # Save the image
    image.save(output_image)
    print(f"Saved glyph overview: {output_image}")


# Example usage
woff_file = "khuree_font/CMSUB.TTF"
# woff_file = "khuree_font/cmsulaanbaatardp-webfont.woff"
output_image = "glyph_visualization_char.png"
chars = unique_chars

visualize_chars_in_font(woff_file, output_image, chars)
# Out:
# Saved glyph overview: glyph_visualization_char.png

# %%
vocab = ""
for char in unique_chars:
    print(char)
    vocab += char
vocab
# Out:
# B
# 2
# =
# q
# Q
# 9
# 8
# {
# #
# k
# [
# }
# c
# M
# P
# 1
# h
# $
# s
# p
# ]
# a
# ,
# )
# y
# o
# L
# w
# e
# A
# %
# D
# E
# :
# m
# |
# i
# b
# +
# j
# t
# G
# F
# <
# S
# O
# .
# /
# 7
# @
# n
# ~
# Z
# `
# Y
# !
# >
# f
# 6
# z
# 4
# C
# R
# -
# I
# N
# T
# "
# u
# U
# l
# ^
# d
# K
# _
# g
# 5
# 0
# *
# &
# \
# (
# J
# ?
# ;
# 3
# r
# H
# W
# 'B2=qQ98{#k[}cMP1h$sp]a,)yoLweA%DE:m|ib+jtGF<SO./7@n~Z`Y!>f6z4CR-INT"uUl^dK_g50*&\\(J?;3rHW'

# %%
image = Image.new('RGB', (300, 50), color=(255, 255, 255))  # White background
draw = ImageDraw.Draw(image)
font = TTFont("khuree_font/CMSUB.TTF")
# Load the font to render the character
try:
    font_path = font.reader.file.name  # Path to the font file
    image_font = ImageFont.truetype(font_path, 40)  # Adjust font size as needed
except Exception as e:
    print(f"Error loading font: {e}")
# Draw the Unicode character on the image
draw.text((5, 5), f"m o e h g e &", font=image_font, fill=(0, 0, 0))  # Black text


image.save("test.png")

# %%
from PIL import Image, ImageDraw, ImageFont
import freetype

# Function to render text using the WOFF font
def render_text_to_image(text, font_path, output_image_path):
    # Load the WOFF font with FreeType
    face = freetype.Face(font_path)
    
    # Set font size (this may require adjustments depending on the font)
    face.set_char_size(48*64)  # Set size in points (48 points here)
    
    # Calculate the size of the text in the image
    width, height, baseline = 0, 0, 0
    for char in text:
        face.load_char(char)
        glyph = face.glyph
        width += glyph.advance.x >> 6  # advance.x is in 64th units of pixels
        height = max(height, glyph.bitmap_top)
        baseline = max(baseline, glyph.bitmap_top)

    # Create a blank image
    img = Image.new("RGB", (width, height + baseline), "black")
    draw = ImageDraw.Draw(img)
    
    # Position the text
    x = 0
    for char in text:
        # Load the character from the font
        face.load_char(char)
        glyph = face.glyph
        
        # Render the glyph bitmap to the image
        bitmap = glyph.bitmap
        bitmap_width, bitmap_height = bitmap.width, bitmap.rows
        
        if bitmap_width == 0 or bitmap_height == 0:
            continue

        # Create a PIL image from the bitmap data
        glyph_image = Image.new("L", (bitmap_width, bitmap_height))
        glyph_image.putdata(bitmap.buffer)
        
        # Paste the glyph image onto the main image at the correct position
        img.paste(glyph_image, (x + glyph.bitmap_left, baseline - glyph.bitmap_top))
        
        # Move to the next character's position
        x += glyph.advance.x >> 6  # Move the cursor by the glyph's advance width
    
    # Save the result as an image
    img.save(output_image_path)
    # img.show()  # Optional: Display the image

# Path to the WOFF font file
woff_font_path = "CMsHureedp.woff"
text_to_render = "multi_v7_1"

# Path to save the generated image
output_image_path = "test.png"

# Render the text to image
render_text_to_image(text_to_render, woff_font_path, output_image_path)

# %%
import json
from collections import Counter

# Load the scraped JSON data
with open("cleaned_data.json", "r", encoding="utf-8") as f:
    data = json.load(f)

# Initialize character and word counters
char_counter = Counter()
word_counter = Counter()
total_word_count = 0

# Process each extracted text
for entry in data:
    text = entry["text"]
    
    # Count characters
    char_counter.update(text)
    
    # Count words (splitting by whitespace)
    words = text.split()
    word_counter.update(words)
    total_word_count += len(words)

# Get unique counts
unique_chars = len(char_counter)
unique_words = len(word_counter)

# Print results
print(f"Total unique characters: {unique_chars}")
print(f"Character frequencies: {dict(char_counter)}")
print(f"Total words: {total_word_count}")
print(f"Total unique words: {unique_words}")
# Out:
# Total unique characters: 94
# Character frequencies: {'b': 59283, 'u': 27597, 'l': 120067, 'i': 251125, 't': 41194, '\xa0': 132848, 'o': 304666, 'a': 176760, ' ': 440195, 'D': 64548, 'g': 61292, 'e': 436514, '&': 39070, '1': 8140, '7': 1647, 'd': 100118, '*': 36064, 'J': 19522, 'r': 87437, 'O': 84099, '<': 13866, 'f': 107136, 's': 44569, '>': 13830, 'k': 74344, 'E': 103977, 'm': 31602, 'K': 36875, 'M': 18282, 'H': 22940, 'B': 32473, 'S': 28857, '%': 8477, 'N': 20932, 'h': 36135, '_': 11439, 'Y': 12430, 'c': 38491, 'I': 69844, 'C': 9189, ',': 41053, 'j': 37355, '0': 9018, '^': 9470, '(': 13674, '.': 18711, '\r': 34193, '\n': 34192, '\t': 3652, 'y': 15553, '9': 1992, '3': 2748, 'Z': 1869, 'A': 10550, '8': 1680, '6': 1784, 'G': 9568, '5': 2623, ')': 13245, 'n': 19306, '2': 8541, '4': 2396, 'w': 9527, 'W': 572, ']': 582, '-': 8997, '=': 1940, 'L': 1708, ':': 238, '"': 241, '$': 2399, 'T': 20726, '[': 1347, 'q': 784, 'z': 432, '|': 1424, '?': 742, '~': 764, 'P': 1226, '!': 469, '`': 49, 'p': 2513, '{': 126, 'R': 521, 'Q': 194, '\\': 2931, '#': 201, 'F': 1397, '}': 65, 'U': 13342, '@': 50, '+': 56, ';': 631, '/': 11}
# Total words: 578170
# Total unique words: 29352

# %%
unique_chars = set()

for word, count in word_counter.items():
    # Only consider the word if it doesn't contain unrenderable characters
    for char in word:
        unique_chars.add(char)

# %%
len(unique_chars)
# Out:
# 89

# %%
import json

# Special characters handling
# replace_with_space = "\u00A0"  # Non-breaking space (NBSP)
remove_chars = [
    "\u200C",  # Zero-width non-joiner (ZWNJ)
    "\u00AD",  # Soft hyphen (SHY)
]

# Load the scraped JSON data
with open("scraped_data.json", "r", encoding="utf-8") as f:
    data = json.load(f)

# Clean the data
for entry in data:
    text = entry["text"]
    
    # Replace non-breaking space with regular space
    # text = text.replace(replace_with_space, " ")

    # Remove unwanted characters
    for char in remove_chars:
        text = text.replace(char, "")

    entry["text"] = text

# Save the cleaned data
with open("cleaned_data.json", "w", encoding="utf-8") as f:
    json.dump(data, f, ensure_ascii=False, indent=4)

print("Cleaning complete. Saved as 'cleaned_data.json'.")
# Out:
# Cleaning complete. Saved as 'cleaned_data.json'.

# %%
from PIL import Image, ImageDraw, ImageFont
khuree_font_path = "khuree_font/CMSUB.TTF"

def khuree2img(text, output_path="test.png", padding=20):
    try:
        # Load the font
        image_font = ImageFont.truetype(khuree_font_path, 40)  
    except Exception as e:
        print(f"Error loading font: {e}")
        return

    dummy_img = Image.new("RGB", (1, 1))
    draw = ImageDraw.Draw(dummy_img)
    text_width, text_height = draw.textbbox((0, 0), text, font=image_font)[2:]

    img_width = text_width + 2 * padding
    img_height = text_height + 2 * padding

    # Create image
    image = Image.new("RGB", (img_width, img_height), color=(255, 255, 255))
    draw = ImageDraw.Draw(image)

    # Calculate text position (centered)
    text_x = (img_width - text_width) // 2
    text_y = (img_height - text_height) // 2

    # Draw text
    draw.text((text_x, text_y), text, font=image_font, fill=(0, 0, 0))  

    # Save the image
    image.save(output_path)

# Example usage
khuree2img("Moehgo& fca", "test.png")

# %%
import uuid
data=[]
i=0
for word in word_counter:
    if i%100==99:
        print(f"{i+1}/{len(word_counter)}")
    image_path = f"../../dataset/khumuun_bichig/{i}.png"
    data.append({
                    "image_path": image_path,
                    "label": word,
                })
    i+=1
    # khuree2img(word, image_path)
json_path ="../../dataset/khuree_data.json"
with open(json_path, "w", encoding="utf-8") as f:
    json.dump(data, f, ensure_ascii=False, indent=4)

print(f"Saved metadata to {json_path}")
# Out:
# 100/29352
# 200/29352
# 300/29352
# 400/29352
# 500/29352
# 600/29352
# 700/29352
# 800/29352
# 900/29352
# 1000/29352
# 1100/29352
# 1200/29352
# 1300/29352
# 1400/29352
# 1500/29352
# 1600/29352
# 1700/29352
# 1800/29352
# 1900/29352
# 2000/29352
# 2100/29352
# 2200/29352
# 2300/29352
# 2400/29352
# 2500/29352
# 2600/29352
# 2700/29352
# 2800/29352
# 2900/29352
# 3000/29352
# 3100/29352
# 3200/29352
# 3300/29352
# 3400/29352
# 3500/29352
# 3600/29352
# 3700/29352
# 3800/29352
# 3900/29352
# 4000/29352
# 4100/29352
# 4200/29352
# 4300/29352
# 4400/29352
# 4500/29352
# 4600/29352
# 4700/29352
# 4800/29352
# 4900/29352
# 5000/29352
# 5100/29352
# 5200/29352
# 5300/29352
# 5400/29352
# 5500/29352
# 5600/29352
# 5700/29352
# 5800/29352
# 5900/29352
# 6000/29352
# 6100/29352
# 6200/29352
# 6300/29352
# 6400/29352
# 6500/29352
# 6600/29352
# 6700/29352
# 6800/29352
# 6900/29352
# 7000/29352
# 7100/29352
# 7200/29352
# 7300/29352
# 7400/29352
# 7500/29352
# 7600/29352
# 7700/29352
# 7800/29352
# 7900/29352
# 8000/29352
# 8100/29352
# 8200/29352
# 8300/29352
# 8400/29352
# 8500/29352
# 8600/29352
# 8700/29352
# 8800/29352
# 8900/29352
# 9000/29352
# 9100/29352
# 9200/29352
# 9300/29352
# 9400/29352
# 9500/29352
# 9600/29352
# 9700/29352
# 9800/29352
# 9900/29352
# 10000/29352
# 10100/29352
# 10200/29352
# 10300/29352
# 10400/29352
# 10500/29352
# 10600/29352
# 10700/29352
# 10800/29352
# 10900/29352
# 11000/29352
# 11100/29352
# 11200/29352
# 11300/29352
# 11400/29352
# 11500/29352
# 11600/29352
# 11700/29352
# 11800/29352
# 11900/29352
# 12000/29352
# 12100/29352
# 12200/29352
# 12300/29352
# 12400/29352
# 12500/29352
# 12600/29352
# 12700/29352
# 12800/29352
# 12900/29352
# 13000/29352
# 13100/29352
# 13200/29352
# 13300/29352
# 13400/29352
# 13500/29352
# 13600/29352
# 13700/29352
# 13800/29352
# 13900/29352
# 14000/29352
# 14100/29352
# 14200/29352
# 14300/29352
# 14400/29352
# 14500/29352
# 14600/29352
# 14700/29352
# 14800/29352
# 14900/29352
# 15000/29352
# 15100/29352
# 15200/29352
# 15300/29352
# 15400/29352
# 15500/29352
# 15600/29352
# 15700/29352
# 15800/29352
# 15900/29352
# 16000/29352
# 16100/29352
# 16200/29352
# 16300/29352
# 16400/29352
# 16500/29352
# 16600/29352
# 16700/29352
# 16800/29352
# 16900/29352
# 17000/29352
# 17100/29352
# 17200/29352
# 17300/29352
# 17400/29352
# 17500/29352
# 17600/29352
# 17700/29352
# 17800/29352
# 17900/29352
# 18000/29352
# 18100/29352
# 18200/29352
# 18300/29352
# 18400/29352
# 18500/29352
# 18600/29352
# 18700/29352
# 18800/29352
# 18900/29352
# 19000/29352
# 19100/29352
# 19200/29352
# 19300/29352
# 19400/29352
# 19500/29352
# 19600/29352
# 19700/29352
# 19800/29352
# 19900/29352
# 20000/29352
# 20100/29352
# 20200/29352
# 20300/29352
# 20400/29352
# 20500/29352
# 20600/29352
# 20700/29352
# 20800/29352
# 20900/29352
# 21000/29352
# 21100/29352
# 21200/29352
# 21300/29352
# 21400/29352
# 21500/29352
# 21600/29352
# 21700/29352
# 21800/29352
# 21900/29352
# 22000/29352
# 22100/29352
# 22200/29352
# 22300/29352
# 22400/29352
# 22500/29352
# 22600/29352
# 22700/29352
# 22800/29352
# 22900/29352
# 23000/29352
# 23100/29352
# 23200/29352
# 23300/29352
# 23400/29352
# 23500/29352
# 23600/29352
# 23700/29352
# 23800/29352
# 23900/29352
# 24000/29352
# 24100/29352
# 24200/29352
# 24300/29352
# 24400/29352
# 24500/29352
# 24600/29352
# 24700/29352
# 24800/29352
# 24900/29352
# 25000/29352
# 25100/29352
# 25200/29352
# 25300/29352
# 25400/29352
# 25500/29352
# 25600/29352
# 25700/29352
# 25800/29352
# 25900/29352
# 26000/29352
# 26100/29352
# 26200/29352
# 26300/29352
# 26400/29352
# 26500/29352
# 26600/29352
# 26700/29352
# 26800/29352
# 26900/29352
# 27000/29352
# 27100/29352
# 27200/29352
# 27300/29352
# 27400/29352
# 27500/29352
# 27600/29352
# 27700/29352
# 27800/29352
# 27900/29352
# 28000/29352
# 28100/29352
# 28200/29352
# 28300/29352
# 28400/29352
# 28500/29352
# 28600/29352
# 28700/29352
# 28800/29352
# 28900/29352
# 29000/29352
# 29100/29352
# 29200/29352
# 29300/29352
# Saved metadata to ../../dataset/khuree_data.json

# %%
char_counter
# Out:
# Counter({' ': 440195,
#          'e': 436514,
#          'o': 304666,
#          'i': 251125,
#          'a': 176760,
#          '\xa0': 132848,
#          'l': 120067,
#          'f': 107136,
#          'E': 103977,
#          'd': 100118,
#          'r': 87437,
#          'O': 84099,
#          'k': 74344,
#          'I': 69844,
#          'D': 64548,
#          'g': 61292,
#          'b': 59283,
#          's': 44569,
#          't': 41194,
#          ',': 41053,
#          '&': 39070,
#          'c': 38491,
#          'j': 37355,
#          'K': 36875,
#          'h': 36135,
#          '*': 36064,
#          '\r': 34193,
#          '\n': 34192,
#          'B': 32473,
#          'm': 31602,
#          'S': 28857,
#          'u': 27597,
#          'H': 22940,
#          'N': 20932,
#          'T': 20726,
#          'J': 19522,
#          'n': 19306,
#          '.': 18711,
#          'M': 18282,
#          'y': 15552,
#          '<': 13866,
#          '>': 13830,
#          '(': 13674,
#          'U': 13342,
#          ')': 13245,
#          'Y': 12430,
#          '_': 11439,
#          'A': 10550,
#          'G': 9568,
#          'w': 9527,
#          '^': 9470,
#          'C': 9189,
#          '0': 9018,
#          '-': 8997,
#          '2': 8541,
#          '%': 8477,
#          '1': 8140,
#          '\t': 3652,
#          '\\': 2931,
#          '3': 2748,
#          '5': 2623,
#          'p': 2513,
#          '$': 2399,
#          '4': 2396,
#          '9': 1992,
#          '=': 1940,
#          'Z': 1869,
#          '6': 1784,
#          'L': 1708,
#          '8': 1680,
#          '7': 1647,
#          '|': 1424,
#          'F': 1397,
#          '[': 1347,
#          'P': 1226,
#          'q': 784,
#          '~': 764,
#          '?': 742,
#          ';': 631,
#          ']': 582,
#          'W': 572,
#          'R': 521,
#          '!': 469,
#          'z': 432,
#          '"': 241,
#          ':': 238,
#          '#': 201,
#          'Q': 194,
#          '{': 126,
#          '}': 65,
#          '+': 56,
#          '@': 50,
#          '`': 49,
#          '/': 11,
#          '\u200c': 1,
#          '\xad': 1,
#          'у': 1})
